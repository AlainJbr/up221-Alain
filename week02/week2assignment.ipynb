# %% [markdown]
# # Week 2 : Assignment
# ## Manipulating datasets

# %%
# importing libraries
import pandas as pd
import geopandas as gpd

# %%
arrets = gpd.read_file('arrets.geojson')
# Out:
# /opt/conda/lib/python3.11/site-packages/geopandas/io/file.py:399: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   as_dt = pd.to_datetime(df[k], errors="ignore")
# /opt/conda/lib/python3.11/site-packages/geopandas/io/file.py:399: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   as_dt = pd.to_datetime(df[k], errors="ignore")

# %%
#checking the file type
type(arrets)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
#seeing what the data looks like
arrets.head()
# Out:
#     arrid       arrversion                arrcreated  \
# 0  463057    1022156-44453 2019-01-28 00:00:00+00:00
# 1  483423  1445357-1370657 2022-01-11 00:00:00+00:00
# 2  483900  1390431-1389589 2022-05-09 20:50:35+00:00
# 3  483904  1390421-1470335 2022-05-10 09:25:24+00:00
# 4  412354     474767-45559 2015-02-12 14:24:46+00:00
#
#                  arrchanged                 arrname arrtype arrpubliccode  \
# 0 2023-11-22 18:44:34+00:00           Pointe du Lac   metro             -
# 1 2023-11-22 18:44:28+00:00  Bagneux - Lucie Aubrac   metro             -
# 2 2023-11-22 18:44:28+00:00            Aimé Césaire   metro             -
# 3 2023-11-22 18:44:28+00:00  Mairie d'Aubervilliers   metro             -
# 4 2023-11-22 18:43:25+00:00  Funiculaire Gare basse   metro             -
#
#    arrxepsg2154  arryepsg2154   zdaid        arrtown arrpostalregion  \
# 0        660629       6852207   44453        Créteil           94028
# 1        649872       6856156  483280        Bagneux           92007
# 2        654417       6867784  483901  Aubervilliers           93001
# 3        654616       6868372  483899  Aubervilliers           93001
# 4        651791       6865165   45559      Paris 18e           75118
#
#   arraccessibility arraudiblesignals arrvisualsigns arrfarezone  \
# 0            false           unknown        unknown           3
# 1            false              true           true           3
# 2            false              true           true           2
# 3            false              true           true           2
# 4            false             false          false           1
#
#                    geometry
# 0  POINT (2.46432 48.76876)
# 1  POINT (2.31750 48.80353)
# 2  POINT (2.37813 48.90844)
# 3  POINT (2.38078 48.91374)
# 4  POINT (2.34260 48.88469)

# %%
#looking at the last entries of the dataframe
arrets.tail(3)
# Out:
#       arrid       arrversion                arrcreated  \
# 780   21909    1460153-43310 2014-12-29 00:00:00+00:00
# 781  463218  1458841-1347826 2019-01-29 00:00:00+00:00
# 782   21916    1458082-45065 2014-12-29 00:00:00+00:00
#
#                    arrchanged            arrname arrtype arrpubliccode  \
# 780 2023-03-28 13:18:07+00:00  Grands Boulevards   metro             -
# 781 2023-03-28 08:26:59+00:00    Louvre - Rivoli   metro             -
# 782 2023-03-07 09:47:45+00:00           Voltaire   metro             -
#
#      arrxepsg2154  arryepsg2154  zdaid    arrtown arrpostalregion  \
# 780        651820       6863688  43310   Paris 2e           75102
# 781        651651       6862521  44645  Paris 1er           75101
# 782        654525       6862145  45065  Paris 11e           75111
#
#     arraccessibility arraudiblesignals arrvisualsigns arrfarezone  \
# 780            false              true           true           1
# 781            false              true           true           1
# 782            false              true           true           1
#
#                      geometry
# 780  POINT (2.34317 48.87141)
# 781  POINT (2.34100 48.86091)
# 782  POINT (2.38021 48.85774)

# %%
#generate a random sample from the dataframe
arrets.sample(5)
# Out:
#       arrid       arrversion                arrcreated  \
# 184   22216  1347828-1347830 2014-12-29 00:00:00+00:00
# 73    22025    1026042-45194 2014-12-29 00:00:00+00:00
# 32    22172    1347699-45313 2014-12-29 00:00:00+00:00
# 648  463180    1347719-43026 2019-01-29 00:00:00+00:00
# 165   22400  1348068-1348067 2014-12-29 00:00:00+00:00
#
#                    arrchanged                           arrname arrtype  \
# 184 2021-10-26 17:52:42+00:00  Maisons-Alfort - Les Juilliottes   metro
# 73  2021-05-04 17:56:37+00:00                    Rue Saint-Maur   metro
# 32  2021-10-26 16:35:09+00:00                      Edgar Quinet   metro
# 648 2021-10-26 16:43:15+00:00             Franklin D. Roosevelt   metro
# 165 2021-10-27 14:43:34+00:00          Villejuif - Louis Aragon   metro
#
#     arrpubliccode  arrxepsg2154  arryepsg2154  zdaid         arrtown  \
# 184             -        659294       6856035  44067  Maisons-Alfort
# 73              -        654549       6862846  45194       Paris 11e
# 32              -        650486       6860315  45313       Paris 14e
# 648             -        649353       6863403  43026        Paris 8e
# 165             -        653555       6854347  45049       Villejuif
#
#     arrpostalregion arraccessibility arraudiblesignals arrvisualsigns  \
# 184           94046            false              true           true
# 73            75111            false              true           true
# 32            75114            false              true           true
# 648           75108            false              true           true
# 165           94076            false              true           true
#
#     arrfarezone                  geometry
# 184           2  POINT (2.44579 48.80311)
# 73            1  POINT (2.38046 48.86404)
# 32            1  POINT (2.32537 48.84098)
# 648           1  POINT (2.30957 48.86866)
# 165           2  POINT (2.36784 48.78754)

# %%
#getting information about the type pf each column in the df
arrets.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 783 entries, 0 to 782
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   arrid              783 non-null    object
#  1   arrversion         783 non-null    object
#  2   arrcreated         783 non-null    datetime64[ns, UTC]
#  3   arrchanged         783 non-null    datetime64[ns, UTC]
#  4   arrname            783 non-null    object
#  5   arrtype            783 non-null    object
#  6   arrpubliccode      783 non-null    object
#  7   arrxepsg2154       783 non-null    int64
#  8   arryepsg2154       783 non-null    int64
#  9   zdaid              783 non-null    object
#  10  arrtown            783 non-null    object
#  11  arrpostalregion    783 non-null    object
#  12  arraccessibility   783 non-null    object
#  13  arraudiblesignals  783 non-null    object
#  14  arrvisualsigns     783 non-null    object
#  15  arrfarezone        783 non-null    object
#  16  geometry           783 non-null    geometry
# dtypes: datetime64[ns, UTC](2), geometry(1), int64(2), object(12)
# memory usage: 104.1+ KB

# %%
#knowing the dimensions of the df
arrets.shape
# Out:
# (783, 17)

# %%
arrets.columns.to_list()
# Out:
# ['arrid',
#  'arrversion',
#  'arrcreated',
#  'arrchanged',
#  'arrname',
#  'arrtype',
#  'arrpubliccode',
#  'arrxepsg2154',
#  'arryepsg2154',
#  'zdaid',
#  'arrtown',
#  'arrpostalregion',
#  'arraccessibility',
#  'arraudiblesignals',
#  'arrvisualsigns',
#  'arrfarezone',
#  'geometry']

# %%
arrets['arrtown'].value_counts()
# Out:
# arrtown
# Paris 15e               52
# Paris 12e               46
# Paris 8e                44
# Paris 19e               42
# Paris 16e               42
# Paris 10e               42
# Paris 11e               41
# Paris 13e               40
# Paris 9e                38
# Paris 18e               36
# Paris 17e               33
# Paris 14e               27
# Paris 20e               26
# Paris 1er               26
# Paris 7e                26
# Paris 6e                23
# Paris 4e                19
# Paris 2e                19
# Paris 3e                16
# Paris 5e                14
# Boulogne-Billancourt    10
# Saint-Denis             10
# Saint-Ouen               8
# Créteil                  8
# Aubervilliers            7
# Levallois-Perret         6
# Maisons-Alfort           6
# Montreuil                6
# Villejuif                6
# Pantin                   6
# Bagneux                  5
# Charenton-le-Pont        4
# Issy-les-Moulineaux      4
# Malakoff                 4
# Neuilly-sur-Seine        4
# Ivry-sur-Seine           4
# Asnières-sur-Seine       3
# Bobigny                  3
# Gennevilliers            3
# Le Kremlin-Bicêtre       2
# Les Lilas                2
# Clichy                   2
# La Courneuve             2
# Montrouge                2
# Antony                   2
# Courbevoie               2
# Bagnolet                 2
# Puteaux                  2
# Saint-Mandé              2
# Châtillon                2
# Vincennes                2
# Name: count, dtype: int64

# %%
#transforming arrtown into a list
arrtown = arrets['arrtown'].value_counts()
print (arrtown)
# Out:
# arrtown
# Paris 15e               52
# Paris 12e               46
# Paris 8e                44
# Paris 19e               42
# Paris 16e               42
# Paris 10e               42
# Paris 11e               41
# Paris 13e               40
# Paris 9e                38
# Paris 18e               36
# Paris 17e               33
# Paris 14e               27
# Paris 20e               26
# Paris 1er               26
# Paris 7e                26
# Paris 6e                23
# Paris 4e                19
# Paris 2e                19
# Paris 3e                16
# Paris 5e                14
# Boulogne-Billancourt    10
# Saint-Denis             10
# Saint-Ouen               8
# Créteil                  8
# Aubervilliers            7
# Levallois-Perret         6
# Maisons-Alfort           6
# Montreuil                6
# Villejuif                6
# Pantin                   6
# Bagneux                  5
# Charenton-le-Pont        4
# Issy-les-Moulineaux      4
# Malakoff                 4
# Neuilly-sur-Seine        4
# Ivry-sur-Seine           4
# Asnières-sur-Seine       3
# Bobigny                  3
# Gennevilliers            3
# Le Kremlin-Bicêtre       2
# Les Lilas                2
# Clichy                   2
# La Courneuve             2
# Montrouge                2
# Antony                   2
# Courbevoie               2
# Bagnolet                 2
# Puteaux                  2
# Saint-Mandé              2
# Châtillon                2
# Vincennes                2
# Name: count, dtype: int64

# %%
#transforming the list into a df
arrtown = arrtown.reset_index()
arrtown
# Out:
#     index               arrtown  count
# 0       0             Paris 15e     52
# 1       1             Paris 12e     46
# 2       2              Paris 8e     44
# 3       3             Paris 19e     42
# 4       4             Paris 16e     42
# 5       5             Paris 10e     42
# 6       6             Paris 11e     41
# 7       7             Paris 13e     40
# 8       8              Paris 9e     38
# 9       9             Paris 18e     36
# 10     10             Paris 17e     33
# 11     11             Paris 14e     27
# 12     12             Paris 20e     26
# 13     13             Paris 1er     26
# 14     14              Paris 7e     26
# 15     15              Paris 6e     23
# 16     16              Paris 4e     19
# 17     17              Paris 2e     19
# 18     18              Paris 3e     16
# 19     19              Paris 5e     14
# 20     20  Boulogne-Billancourt     10
# 21     21           Saint-Denis     10
# 22     22            Saint-Ouen      8
# 23     23               Créteil      8
# 24     24         Aubervilliers      7
# 25     25      Levallois-Perret      6
# 26     26        Maisons-Alfort      6
# 27     27             Montreuil      6
# 28     28             Villejuif      6
# 29     29                Pantin      6
# 30     30               Bagneux      5
# 31     31     Charenton-le-Pont      4
# 32     32   Issy-les-Moulineaux      4
# 33     33              Malakoff      4
# 34     34     Neuilly-sur-Seine      4
# 35     35        Ivry-sur-Seine      4
# 36     36    Asnières-sur-Seine      3
# 37     37               Bobigny      3
# 38     38         Gennevilliers      3
# 39     39    Le Kremlin-Bicêtre      2
# 40     40             Les Lilas      2
# 41     41                Clichy      2
# 42     42          La Courneuve      2
# 43     43             Montrouge      2
# 44     44                Antony      2
# 45     45            Courbevoie      2
# 46     46              Bagnolet      2
# 47     47               Puteaux      2
# 48     48           Saint-Mandé      2
# 49     49             Châtillon      2
# 50     50             Vincennes      2

# %%
type(arrtown)
# Out:
# pandas.core.frame.DataFrame

# %%
#list of columns
arrtown.columns.to_list()
# Out:
# ['index', 'arrtown', 'count']

# %%
#dropping the the index because we don't need it twice
arrtown.drop(columns=['index'])
# Out:
#                  arrtown  count
# 0              Paris 15e     52
# 1              Paris 12e     46
# 2               Paris 8e     44
# 3              Paris 19e     42
# 4              Paris 16e     42
# 5              Paris 10e     42
# 6              Paris 11e     41
# 7              Paris 13e     40
# 8               Paris 9e     38
# 9              Paris 18e     36
# 10             Paris 17e     33
# 11             Paris 14e     27
# 12             Paris 20e     26
# 13             Paris 1er     26
# 14              Paris 7e     26
# 15              Paris 6e     23
# 16              Paris 4e     19
# 17              Paris 2e     19
# 18              Paris 3e     16
# 19              Paris 5e     14
# 20  Boulogne-Billancourt     10
# 21           Saint-Denis     10
# 22            Saint-Ouen      8
# 23               Créteil      8
# 24         Aubervilliers      7
# 25      Levallois-Perret      6
# 26        Maisons-Alfort      6
# 27             Montreuil      6
# 28             Villejuif      6
# 29                Pantin      6
# 30               Bagneux      5
# 31     Charenton-le-Pont      4
# 32   Issy-les-Moulineaux      4
# 33              Malakoff      4
# 34     Neuilly-sur-Seine      4
# 35        Ivry-sur-Seine      4
# 36    Asnières-sur-Seine      3
# 37               Bobigny      3
# 38         Gennevilliers      3
# 39    Le Kremlin-Bicêtre      2
# 40             Les Lilas      2
# 41                Clichy      2
# 42          La Courneuve      2
# 43             Montrouge      2
# 44                Antony      2
# 45            Courbevoie      2
# 46              Bagnolet      2
# 47               Puteaux      2
# 48           Saint-Mandé      2
# 49             Châtillon      2
# 50             Vincennes      2

# %%
#changing the name of the colums
arrtown.columns = ['index','Ville', 'Nombre']

# %%
# plotting a bar chart
arrtown.plot.bar(x = 'Ville', y = 'Nombre', title = 'Nombre d`arrêts par commune', color = 'tab:red')
# Out:
# <Axes: title={'center': 'Nombre d`arrêts par commune'}, xlabel='Ville'>

# %%
#trimming the df
arrets[['arrname', 'arrtown', 'geometry']]
# Out:
#                     arrname        arrtown                  geometry
# 0             Pointe du Lac        Créteil  POINT (2.46432 48.76876)
# 1    Bagneux - Lucie Aubrac        Bagneux  POINT (2.31750 48.80353)
# 2              Aimé Césaire  Aubervilliers  POINT (2.37813 48.90844)
# 3    Mairie d'Aubervilliers  Aubervilliers  POINT (2.38078 48.91374)
# 4    Funiculaire Gare basse      Paris 18e  POINT (2.34260 48.88469)
# ..                      ...            ...                       ...
# 778               Boucicaut      Paris 15e  POINT (2.28779 48.84112)
# 779                Mabillon       Paris 6e  POINT (2.33509 48.85296)
# 780       Grands Boulevards       Paris 2e  POINT (2.34317 48.87141)
# 781         Louvre - Rivoli      Paris 1er  POINT (2.34100 48.86091)
# 782                Voltaire      Paris 11e  POINT (2.38021 48.85774)
#
# [783 rows x 3 columns]

# %%
#defining the desired columns in a list
desired= ['arrname','arrtown', 'geometry']

# %%
#Copying a new dataframe with the desired columns
arrets_trimmed = arrets[desired].copy()

# %%
#Querry on Paris 15e
arrets_trimmed.loc[arrets_trimmed['arrtown']=='Paris 15e']
# Out:
#                          arrname    arrtown                  geometry
# 21        Montparnasse Bienvenue  Paris 15e  POINT (2.32085 48.84229)
# 24   La Motte-Picquet - Grenelle  Paris 15e  POINT (2.29896 48.84877)
# 44                    Bir-Hakeim  Paris 15e  POINT (2.28940 48.85393)
# 49                   Volontaires  Paris 15e  POINT (2.30791 48.84153)
# 50                     Vaugirard  Paris 15e  POINT (2.30098 48.83954)
# 84                   Félix Faure  Paris 15e  POINT (2.29185 48.84268)
# 85                        Balard  Paris 15e  POINT (2.27851 48.83665)
# 98               Charles Michels  Paris 15e  POINT (2.28562 48.84660)
# 137          Porte de Versailles  Paris 15e  POINT (2.28774 48.83252)
# 152                      Pasteur  Paris 15e  POINT (2.31291 48.84253)
# 161                      Dupleix  Paris 15e  POINT (2.29366 48.85041)
# 174       Montparnasse Bienvenue  Paris 15e  POINT (2.32399 48.84382)
# 185  La Motte-Picquet - Grenelle  Paris 15e  POINT (2.29875 48.84951)
# 186  La Motte-Picquet - Grenelle  Paris 15e  POINT (2.29891 48.84870)
# 187        Javel - André Citroën  Paris 15e  POINT (2.27804 48.84609)
# 207            Avenue Émile Zola  Paris 15e  POINT (2.29505 48.84696)
# 218                     Commerce  Paris 15e  POINT (2.29385 48.84458)
# 239          Porte de Versailles  Paris 15e  POINT (2.28813 48.83230)
# 257                    Cambronne  Paris 15e  POINT (2.30294 48.84754)
# 260                    Boucicaut  Paris 15e  POINT (2.28792 48.84102)
# 277                      Dupleix  Paris 15e  POINT (2.29364 48.85038)
# 366  La Motte-Picquet - Grenelle  Paris 15e  POINT (2.29849 48.84967)
# 367  La Motte-Picquet - Grenelle  Paris 15e  POINT (2.29853 48.84963)
# 388                     Commerce  Paris 15e  POINT (2.29369 48.84464)
# 389                      Lourmel  Paris 15e  POINT (2.28204 48.83879)
# 391                    Falguière  Paris 15e  POINT (2.31751 48.84444)
# 392                      Pasteur  Paris 15e  POINT (2.31255 48.84296)
# 405                    Falguière  Paris 15e  POINT (2.31755 48.84432)
# 424              Sèvres-Lecourbe  Paris 15e  POINT (2.30947 48.84558)
# 432                        Duroc  Paris 15e  POINT (2.31628 48.84668)
# 442                       Balard  Paris 15e  POINT (2.27836 48.83667)
# 456                  Félix Faure  Paris 15e  POINT (2.29175 48.84275)
# 488                      Pasteur  Paris 15e  POINT (2.31265 48.84282)
# 501                    Vaugirard  Paris 15e  POINT (2.30107 48.83944)
# 510       Montparnasse Bienvenue  Paris 15e  POINT (2.32122 48.84213)
# 511       Montparnasse Bienvenue  Paris 15e  POINT (2.32127 48.84205)
# 512       Montparnasse Bienvenue  Paris 15e  POINT (2.32392 48.84374)
# 517        Javel - André Citroën  Paris 15e  POINT (2.27801 48.84618)
# 529                   Bir-Hakeim  Paris 15e  POINT (2.28930 48.85388)
# 548                   Convention  Paris 15e  POINT (2.29636 48.83713)
# 551                  Volontaires  Paris 15e  POINT (2.30798 48.84141)
# 564                      Lourmel  Paris 15e  POINT (2.28224 48.83866)
# 617                   Convention  Paris 15e  POINT (2.29639 48.83714)
# 632       Montparnasse Bienvenue  Paris 15e  POINT (2.32098 48.84231)
# 640  La Motte-Picquet - Grenelle  Paris 15e  POINT (2.29868 48.84953)
# 666            Avenue Émile Zola  Paris 15e  POINT (2.29502 48.84704)
# 700                      Pasteur  Paris 15e  POINT (2.31279 48.84248)
# 724              Sèvres-Lecourbe  Paris 15e  POINT (2.30953 48.84565)
# 725                        Ségur  Paris 15e  POINT (2.30714 48.84717)
# 732              Charles Michels  Paris 15e  POINT (2.28562 48.84636)
# 743                    Cambronne  Paris 15e  POINT (2.30290 48.84749)
# 778                    Boucicaut  Paris 15e  POINT (2.28779 48.84112)

# %%
arrets_trimmed.loc[arrets_trimmed['arrtown'] == 'Châtillon']
# Out:
#                  arrname    arrtown                  geometry
# 93   Châtillon-Montrouge  Châtillon  POINT (2.30160 48.81073)
# 688  Châtillon-Montrouge  Châtillon  POINT (2.30172 48.81075)

# %%
#plotting the points
arrets_trimmed.plot()
# Out:
# <Axes: >

# %%
#a better plot
arrets_trimmed.plot(
            figsize=(20,12),   #size of the plot (a bit bigger than the default)
            column = 'arrtown',   # column that defines the color of the dots
            legend = True,     # add a legend           
            legend_kwds={
               'loc': 'upper left',
               'bbox_to_anchor':(1,1)
            }                  # this puts the legend to the side
)
# Out:
# <Axes: >

# %%
import folium

# %%
#We need to extract the lat and long fromt the geometry to create a folium map?

# %%
m = folium.Map()
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae383aedcc9ffeee15c2f8f2951ebbb5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae383aedcc9ffeee15c2f8f2951ebbb5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae383aedcc9ffeee15c2f8f2951ebbb5 = L.map(
#                 &quot;map_ae383aedcc9ffeee15c2f8f2951ebbb5&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d49ff144d3ff4d2e2c061f8936f95c6d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d49ff144d3ff4d2e2c061f8936f95c6d.addTo(map_ae383aedcc9ffeee15c2f8f2951ebbb5);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
